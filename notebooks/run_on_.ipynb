# %% [markdown]
# <a href="https://colab.research.google.com/github/Om-merkle/AI_CAP_MED_EMBED/blob/main/notebooks/run_on_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🩺 Medical Embedding Fine-Tuning — run on Colab (free T4 GPU)
#
# End-to-end on the **complete, real medical datasets** pulled straight from the Hugging Face Hub:
# prepare data → collect (query, positive, negative) triplets → MTEB medical baseline →
# fine-tune (**3 epochs**) → evaluate → before/after comparison.
#
# **Setup (one time):** Runtime → **Change runtime type** → Hardware accelerator = **T4 GPU**.

# %%
# Cell 0 — confirm the GPU is on (should print a Tesla T4)
# !nvidia-smi -L
# Out:
# GPU 0: Tesla T4 (UUID: GPU-b65bf531-3727-0e5c-eb91-e9d7d93167bd)

# %%
# Cell 1 — clone the project + install dependencies (~2 min)
REPO_URL = "https://github.com/Om-merkle/AI_CAP_MED_EMBED"  # <-- set your repo URL

# !git clone {REPO_URL} project
# %cd project
# !pip install -q -r requirements.txt
# Out:
# Cloning into 'project'...
# remote: Enumerating objects: 151, done.
# remote: Counting objects: 100% (151/151), done.
# remote: Compressing objects: 100% (94/94), done.
# remote: Total 151 (delta 76), reused 118 (delta 50), pack-reused 0 (from 0)
# Receiving objects: 100% (151/151), 4.85 MiB | 15.67 MiB/s, done.
# Resolving deltas: 100% (76/76), done.
# /content/project
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 58.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 117.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 103.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.8/304.8 kB 23.5 MB/s eta 0:00:00

# %%
# Cell 2 — optional Hugging Face connection (higher rate limits + enables Hub push).
# Add a secret named HF_TOKEN in Colab's key icon (left sidebar) to use it.
# The datasets are public, so this cell is a safe no-op without a token.
import os
try:
    from google.colab import userdata
    os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN")
    print("HF_TOKEN loaded from Colab secrets ✅")
except Exception:
    print("No HF_TOKEN secret found — continuing anonymously (fine for public datasets).")
# Out:
# No HF_TOKEN secret found — continuing anonymously (fine for public datasets).

# %%
# Cell 3 — pull the COMPLETE datasets from the Hugging Face Hub (~3-5 min):
#   * all 33,955 medical flashcards (medalpaca)
#   * all ~232,000 MedEmbed clinical triplets (abhinand/MedEmbed-training-triplets-v1)
# This overwrites the small starter sample bundled in data/raw/.
# !python scripts/download_dataset.py
# !wc -l data/raw/*.jsonl
# Out:
# Downloading medalpaca/medical_meadow_medical_flashcards ...
# README.md: 100% 1.24k/1.24k [00:00<00:00, 3.32MB/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# medical_meadow_wikidoc_medical_flashcard(…): 100% 17.7M/17.7M [00:01<00:00, 15.9MB/s]
# Generating train split: 100% 33955/33955 [00:00<00:00, 82170.65 examples/s]
#   wrote 33955 rows -> /content/project/data/raw/medical_flashcards.jsonl
# Downloading abhinand/MedEmbed-training-triplets-v1 (COMPLETE, ~232k rows) ...
# README.md: 100% 6.36k/6.36k [00:00<00:00, 13.9MB/s]
# data/train-00000-of-00001.parquet: 100% 59.7M/59.7M [00:01<00:00, 32.8MB/s]
# Generating train split: 100% 232684/232684 [00:00<00:00, 342538.41 examples/s]
#   wrote 232684 rows -> /content/project/data/raw/medembed_triplets.jsonl
#
# Done. The `flashcards` and `medembed` domains now run fully offline.
# (`nfcorpus` streams BeIR/nfcorpus from the HF Hub on first use.)
#    232684 data/raw/medembed_triplets.jsonl
#     33955 data/raw/medical_flashcards.jsonl
#    266639 total

# %% [markdown]
# ## Path A — one-shot pipeline, 3 epochs + 4 medical benchmarks (recommended)
#
# Pick a medical domain:
# - `nfcorpus` — BeIR medical/nutrition IR (honest before/after on its own benchmark)
# - `medembed` — the complete 232k MedEmbed clinical triplets with expert negatives (mining skipped)
# - `flashcards` — 34k medical Q/A flashcards
#
# The pipeline evaluates the **base and fine-tuned models on 4 medical MTEB benchmarks**
# (MedicalQARetrieval, PublicHealthQA, NFCorpus, ArguAna) and shows per-benchmark
# before/after/delta in the comparison and the leaderboard. Add TRECCOVID (the 5th,
# ~171k docs, slow) with `--mteb-tasks all`. `--benchmark` additionally compares candidate
# models (MiniLM vs BGE vs the published MedEmbed) on your triplets — plus any **closed-source
# baselines** (e.g. `openai:text-embedding-3-small`) automatically when `OPENAI_API_KEY` is set.
# Closed-source models are compared only, never fine-tuned. Fine-tune **several open-source
# models at once** with `--base-models a,b,c` (see *More experiments* below).
#
# Expect roughly 60–90 min on a T4 (training + 4 benchmarks × 2 models); add `--no-mteb`
# for a fast training-only run.

# %%
# Optional — load OPENAI_API_KEY so the closed-source OpenAI baselines run (they are
# compared against, never fine-tuned). Add a secret named OPENAI_API_KEY via Colab's key
# icon (left sidebar). Safe no-op if absent — the pipeline just skips the openai: baselines.
import os
try:
    from google.colab import userdata
    os.environ["OPENAI_API_KEY"] = userdata.get("OPENAI_API_KEY")
    print("OPENAI_API_KEY loaded from Colab secrets ✅")
except Exception:
    print("No OPENAI_API_KEY secret found — closed-source (openai:) baselines will be skipped.")
# Out:
# OPENAI_API_KEY loaded from Colab secrets ✅

# %%
# !python run_pipeline.py --domain nfcorpus --base-model BAAI/bge-small-en-v1.5 \
    --epochs 3 --batch-size 32 --benchmark --run-label colab-nfcorpus-3ep
# Out:
# [device] cuda  |  base_models=BAAI/bge-small-en-v1.5  domain=nfcorpus  primary_task=NFCorpus
# [benchmarks] MedicalQARetrieval, PublicHealthQA, NFCorpus, ArguAna
#
# [data] Preparing medical data ...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md: 100% 10.5k/10.5k [00:00<00:00, 20.3MB/s]
# corpus/corpus-00000-of-00001.parquet: 100% 3.16M/3.16M [00:01<00:00, 3.07MB/s]
# Generating corpus split: 100% 3633/3633 [00:00<00:00, 69766.80 examples/s]
# queries/queries-00000-of-00001.parquet: 100% 80.9k/80.9k [00:00<00:00, 131kB/s]
# Generating queries split: 100% 3237/3237 [00:00<00:00, 436558.27 examples/s]
# README.md: 100% 14.0k/14.0k [00:00<00:00, 24.1MB/s]
# train.tsv: 100% 2.50M/2.50M [00:00<00:00, 113MB/s]
# dev.tsv: 100% 258k/258k [00:00<00:00, 116MB/s]
# test.tsv: 100% 280k/280k [00:00<00:00, 140MB/s]
# Generating train split: 100% 110575/110575 [00:00<00:00, 881117.80 examples/s]
# Generating validation split: 100% 11385/11385 [00:00<00:00, 644506.77 examples/s]
# Generating test split: 100% 12334/12334 [00:00<00:00, 627106.77 examples/s]
# {
#   "domain": "nfcorpus",
#   "num_pairs": 110575,
#   "num_eval_queries": 100,
#   "eval_corpus_size": 3633,
#   "pairs_path": "/content/project/data/pairs.jsonl",
#   "eval_path": "/content/project/data/eval.json"
# }
#
# [triplets] Collecting triplets ...
# modules.json: 100% 349/349 [00:00<00:00, 1.29MB/s]
# config_sentence_transformers.json: 100% 124/124 [00:00<00:00, 577kB/s]
# README.md: 100% 94.8k/94.8k [00:00<00:00, 75.7MB/s]
# sentence_bert_config.json: 100% 52.0/52.0 [00:00<00:00, 153kB/s]
# config.json: 100% 743/743 [00:00<00:00, 2.63MB/s]
# model.safetensors: 100% 133M/133M [00:01<00:00, 86.8MB/s]
# Loading weights: 100% 199/199 [00:00<00:00, 4087.94it/s]
# tokenizer_config.json: 100% 366/366 [00:00<00:00, 1.18MB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 24.9MB/s]
# tokenizer.json: 100% 711k/711k [00:00<00:00, 62.1MB/s]
# special_tokens_map.json: 100% 125/125 [00:00<00:00, 489kB/s]
# config.json: 100% 190/190 [00:00<00:00, 715kB/s]
# Found 2576 unique queries out of 110575 total queries.
# Found an average of 42.925 positives per query.
# Batches: 100% 111/111 [00:31<00:00,  3.49it/s]
# Batches: 100% 81/81 [00:01<00:00, 59.91it/s]
# Computing similarity scores: 100% 1/1 [00:00<00:00,  4.41it/s]
# Negative candidates mined, preparing dataset...
# Metric       Positive       Negative     Difference
# Count         109,976          8,238
# Mean           0.6226         0.6050         0.0583
# Median         0.6216         0.6105         0.0459
# Std            0.0775         0.0602         0.0538
# Min            0.3325         0.4269         0.0001
# 25%            0.5698         0.5648         0.0133
# 50%            0.6216         0.6105         0.0459
# 75%            0.6735         0.6438         0.0888
# Max            0.9304         0.7939         0.2800
# Skipped 3,331,669 potential negatives (83.93%) due to the absolute_margin of 0.0.
# Could not find enough negatives for 321690 samples (97.50%). Consider adjusting the range_max, range_min and absolute_margin parameters if you'd like to find more valid negatives.
# {
#   "source": "mined (hard negatives via the base model)",
#   "num_triplets": 8238,
#   "num_negatives_per_pair": 3,
#   "triplets_path": "/content/project/data/triplets.jsonl",
#   "columns": [
#     "anchor",
#     "positive",
#     "negative"
#   ]
# }
#
# [extra] Benchmarking candidate models on the domain triplets (open-source + closed-source baselines) ...
# modules.json: 100% 349/349 [00:00<00:00, 1.50MB/s]
# config_sentence_transformers.json: 100% 116/116 [00:00<00:00, 488kB/s]
# README.md: 100% 10.5k/10.5k [00:00<00:00, 18.5MB/s]
# sentence_bert_config.json: 100% 53.0/53.0 [00:00<00:00, 61.3kB/s]
# config.json: 100% 612/612 [00:00<00:00, 2.66MB/s]
# model.safetensors: 100% 90.9M/90.9M [00:01<00:00, 75.8MB/s]
# Loading weights: 100% 103/103 [00:00<00:00, 4509.06it/s]
# tokenizer_config.json: 100% 350/350 [00:00<00:00, 1.48MB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 20.0MB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 53.6MB/s]
# special_tokens_map.json: 100% 112/112 [00:00<00:00, 403kB/s]
# config.json: 100% 190/190 [00:00<00:00, 858kB/s]
# Loading weights: 100% 199/199 [00:00<00:00, 4738.65it/s]
# modules.json: 100% 349/349 [00:00<00:00, 1.62MB/s]
# config_sentence_transformers.json: 100% 201/201 [00:00<00:00, 924kB/s]
# README.md: 100% 297k/297k [00:00<00:00, 31.8MB/s]
# sentence_bert_config.json: 100% 53.0/53.0 [00:00<00:00, 88.6kB/s]
# config.json: 100% 711/711 [00:00<00:00, 3.24MB/s]
# model.safetensors: 100% 133M/133M [00:01<00:00, 78.5MB/s]
# Loading weights: 100% 199/199 [00:00<00:00, 5232.49it/s]
# tokenizer_config.json: 100% 1.24k/1.24k [00:00<00:00, 2.85MB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 42.6MB/s]
# tokenizer.json: 100% 711k/711k [00:00<00:00, 78.3MB/s]
# special_tokens_map.json: 100% 695/695 [00:00<00:00, 2.87MB/s]
# config.json: 100% 296/296 [00:00<00:00, 1.26MB/s]
# rank  model                                   kind   triplet_accuracy  avg_margin
# 1     BAAI/bge-small-en-v1.5                  local  1.0               0.0709
# 2     abhinand/MedEmbed-small-v0.1            local  0.954             0.0734
# 3     sentence-transformers/all-MiniLM-L6-v2  local  0.934             0.1871
# 4     openai:text-embedding-3-small           api    ERR               -
# 5     openai:text-embedding-3-large           api    ERR               -
#
# ########## base_model = BAAI/bge-small-en-v1.5 ##########
#
# [baseline] MTEB / IR baseline (base model) ...
# Loading weights: 100% 199/199 [00:00<00:00, 4647.29it/s]
# 2026-07-09 08:44:29.467535: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# README.md: 100% 1.24k/1.24k [00:00<00:00, 1.94MB/s]
# default.jsonl: 100% 231k/231k [00:00<00:00, 24.5MB/s]
# corpus.jsonl: 100% 2.51M/2.51M [00:00<00:00, 102MB/s]
# queries.jsonl: 100% 224k/224k [00:00<00:00, 119MB/s]
# README.md: 100% 2.07k/2.07k [00:00<00:00, 5.09MB/s]
# english.csv: 100% 172k/172k [00:00<00:00, 64.1MB/s]
# README.md: 100% 1.46k/1.46k [00:00<00:00, 3.82MB/s]
# train.jsonl: 100% 7.26M/7.26M [00:00<00:00, 217MB/s]
# dev.jsonl: 100% 748k/748k [00:00<00:00, 243MB/s]
# test.jsonl: 100% 810k/810k [00:00<00:00, 122MB/s]
# corpus.jsonl: 100% 5.97M/5.97M [00:01<00:00, 5.73MB/s]
# queries.jsonl: 100% 180k/180k [00:00<00:00, 292kB/s]
# README.md: 100% 1.20k/1.20k [00:00<00:00, 3.27MB/s]
# test.jsonl: 100% 157k/157k [00:00<00:00, 155MB/s]
# corpus.jsonl: 100% 9.69M/9.69M [00:00<00:00, 10.0MB/s]
# queries.jsonl: 100% 1.78M/1.78M [00:00<00:00, 2.70MB/s]
# {
#   "model": "BAAI/bge-small-en-v1.5",
#   "ir": {
#     "ndcg@10": 0.3329,
#     "mrr@10": 0.5386,
#     "map@100": 0.1593,
#     "recall@10": 0.1507,
#     "accuracy@1": 0.41
#   },
#   "mteb": {
#     "task": "NFCorpus",
#     "ndcg@10": 0.3371,
#     "tasks": {
#       "MedicalQARetrieval": {
#         "ndcg@10": 0.6556,
#         "mrr@5": 0.5928
#       },
#       "PublicHealthQA": {
#         "ndcg@10": 0.7618,
#         "mrr@5": 0.706
#       },
#       "NFCorpus": {
#         "ndcg@10": 0.3371,
#         "mrr@5": 0.5219
#       },
#       "ArguAna": {
#         "ndcg@10": 0.595,
#         "mrr@5": 0.4978
#       }
#     }
#   }
# }
#
# [train] Fine-tuning ...
# Loading weights: 100% 199/199 [00:00<00:00, 4031.82it/s]
# {'loss': '2.695', 'grad_norm': '8.046', 'learning_rate': '1.289e-05', 'epoch': '0.1984'}
# {'loss': '2.09', 'grad_norm': '9.32', 'learning_rate': '1.932e-05', 'epoch': '0.3968'}
# {'loss': '1.706', 'grad_norm': '7.489', 'learning_rate': '1.785e-05', 'epoch': '0.5952'}
# {'loss': '1.542', 'grad_norm': '8.947', 'learning_rate': '1.638e-05', 'epoch': '0.7937'}
# {'loss': '1.414', 'grad_norm': '9.669', 'learning_rate': '1.491e-05', 'epoch': '0.9921'}
# {'loss': '1.173', 'grad_norm': '7.894', 'learning_rate': '1.344e-05', 'epoch': '1.19'}
# {'loss': '1.145', 'grad_norm': '7.837', 'learning_rate': '1.197e-05', 'epoch': '1.389'}
# {'loss': '0.9847', 'grad_norm': '8.408', 'learning_rate': '1.05e-05', 'epoch': '1.587'}
# {'loss': '0.9754', 'grad_norm': '11.03', 'learning_rate': '9.029e-06', 'epoch': '1.786'}
# {'loss': '0.8767', 'grad_norm': '9.733', 'learning_rate': '7.559e-06', 'epoch': '1.984'}
# {'loss': '0.8138', 'grad_norm': '11.43', 'learning_rate': '6.088e-06', 'epoch': '2.183'}
# {'loss': '0.8245', 'grad_norm': '10.51', 'learning_rate': '4.618e-06', 'epoch': '2.381'}
# {'loss': '0.747', 'grad_norm': '8.211', 'learning_rate': '3.147e-06', 'epoch': '2.579'}
# {'loss': '0.7848', 'grad_norm': '7.668', 'learning_rate': '1.676e-06', 'epoch': '2.778'}
# {'loss': '0.7925', 'grad_norm': '9.034', 'learning_rate': '2.059e-07', 'epoch': '2.976'}
# {'train_runtime': '343.5', 'train_samples_per_second': '70.2', 'train_steps_per_second': '2.201', 'train_loss': '1.234', 'epoch': '3'}
# Writing model shards: 100% 1/1 [00:00<00:00,  4.63it/s]
# {
#   "base_model": "BAAI/bge-small-en-v1.5",
#   "device": "cuda",
#   "fp16": true,
#   "epochs": 3,
#   "batch_size": 32,
#   "num_train_triplets": 8038,
#   "num_holdout_triplets": 200,
#   "output_dir": "/content/project/models/nfcorpus-bge-small-en-v1.5-ft"
# }
#
# [evaluate] Evaluating fine-tuned model ...
# Loading weights: 100% 199/199 [00:00<00:00, 4802.12it/s]
# {
#   "model": "/content/project/models/nfcorpus-bge-small-en-v1.5-ft",
#   "ir": {
#     "ndcg@10": 0.376,
#     "mrr@10": 0.6201,
#     "map@100": 0.185,
#     "recall@10": 0.1733,
#     "accuracy@1": 0.53
#   },
#   "triplet_accuracy": 1.0,
#   "mteb": {
#     "task": "NFCorpus",
#     "ndcg@10": 0.3463,
#     "tasks": {
#       "MedicalQARetrieval": {
#         "ndcg@10": 0.627,
#         "mrr@5": 0.5575
#       },
#       "PublicHealthQA": {
#         "ndcg@10": 0.7349,
#         "mrr@5": 0.6734
#       },
#       "NFCorpus": {
#         "ndcg@10": 0.3463,
#         "mrr@5": 0.5382
#       },
#       "ArguAna": {
#         "ndcg@10": 0.5509,
#         "mrr@5": 0.4531
#       }
#     }
#   }
# }
#
# [compare] Comparison (before vs after) ...
# {
#   "base_model": "BAAI/bge-small-en-v1.5",
#   "finetuned_model": "/content/project/models/nfcorpus-bge-small-en-v1.5-ft",
#   "headline_ir_ndcg@10_delta": 0.0431,
#   "improved": true,
#   "triplet_accuracy_finetuned": 1.0,
#   "rows": [
#     {
#       "metric": "IR ndcg@10",
#       "baseline": 0.3329,
#       "finetuned": 0.376,
#       "delta": 0.0431
#     },
#     {
#       "metric": "IR mrr@10",
#       "baseline": 0.5386,
#       "finetuned": 0.6201,
#       "delta": 0.0815
#     },
#     {
#       "metric": "IR map@100",
#       "baseline": 0.1593,
#       "finetuned": 0.185,
#       "delta": 0.0257
#     },
#     {
#       "metric": "IR recall@10",
#       "baseline": 0.1507,
#       "finetuned": 0.1733,
#       "delta": 0.0226
#     },
#     {
#       "metric": "MTEB MedicalQARetrieval ndcg@10",
#       "baseline": 0.6556,
#       "finetuned": 0.627,
#       "delta": -0.0286
#     },
#     {
#       "metric": "MTEB PublicHealthQA ndcg@10",
#       "baseline": 0.7618,
#       "finetuned": 0.7349,
#       "delta": -0.0269
#     },
#     {
#       "metric": "MTEB NFCorpus ndcg@10",
#       "baseline": 0.3371,
#       "finetuned": 0.3463,
#       "delta": 0.0092
#     },
#     {
#       "metric": "MTEB ArguAna ndcg@10",
#       "baseline": 0.595,
#       "finetuned": 0.5509,
#       "delta": -0.0441
#     }
#   ]
# }
#
# === BAAI/bge-small-en-v1.5: IR nDCG@10 delta = 0.0431  ->  IMPROVED ===
#
# === LEADERBOARD (best first) ===
# rank  run_at               run_label           base_model              domain    epochs  ir_ndcg@10_ft  mteb_MedicalQARetrieval_ft  mteb_PublicHealthQA_ft  mteb_NFCorpus_ft  mteb_ArguAna_ft  llm_cost_usd
# 1     2026-07-09 08:54:37  colab-nfcorpus-3ep  BAAI/bge-small-en-v1.5  nfcorpus  3       0.376          0.627                       0.7349                  0.3463            0.5509           -

# %%
# Before/after comparison — fine-tuned nDCG@10 should beat the baseline.
import json
print(json.dumps(json.load(open("results/comparison.json")), indent=2))
# Out:
# {
#   "base_model": "BAAI/bge-small-en-v1.5",
#   "finetuned_model": "/content/project/models/nfcorpus-bge-small-en-v1.5-ft",
#   "headline_ir_ndcg@10_delta": 0.0431,
#   "improved": true,
#   "triplet_accuracy_finetuned": 1.0,
#   "rows": [
#     {
#       "metric": "IR ndcg@10",
#       "baseline": 0.3329,
#       "finetuned": 0.376,
#       "delta": 0.0431
#     },
#     {
#       "metric": "IR mrr@10",
#       "baseline": 0.5386,
#       "finetuned": 0.6201,
#       "delta": 0.0815
#     },
#     {
#       "metric": "IR map@100",
#       "baseline": 0.1593,
#       "finetuned": 0.185,
#       "delta": 0.0257
#     },
#     {
#       "metric": "IR recall@10",
#       "baseline": 0.1507,
#       "finetuned": 0.1733,
#       "delta": 0.0226
#     },
#     {
#       "metric": "MTEB MedicalQARetrieval ndcg@10",
#       "baseline": 0.6556,
#       "finetuned": 0.627,
#       "delta": -0.0286
#     },
#     {
#       "metric": "MTEB PublicHealthQA ndcg@10",
#       "baseline": 0.7618,
#       "finetuned": 0.7349,
#       "delta": -0.0269
#     },
#     {
#       "metric": "MTEB NFCorpus ndcg@10",
#       "baseline": 0.3371,
#       "finetuned": 0.3463,
#       "delta": 0.0092
#     },
#     {
#       "metric": "MTEB ArguAna ndcg@10",
#       "baseline": 0.595,
#       "finetuned": 0.5509,
#       "delta": -0.0441
#     }
#   ]
# }

# %%
# Ranked leaderboard of every run so far (persists in results/leaderboard.csv).
from core import leaderboard
leaderboard.to_dataframe()
# Out:
#                 run_at           run_label              base_model    domain  \
# 0  2026-07-09 08:54:37  colab-nfcorpus-3ep  BAAI/bge-small-en-v1.5  nfcorpus
#
#   device epochs batch_size sample_size num_triplets ir_ndcg@10_base  ...  \
# 0   cuda      3         32                     8238          0.3329  ...
#
#   mteb_ArguAna_ft mteb_ArguAna_delta mteb_TRECCOVID_base mteb_TRECCOVID_ft  \
# 0          0.5509            -0.0441
#
#   mteb_TRECCOVID_delta triplet_accuracy llm_model llm_input_tokens  \
# 0                                   1.0
#
#   llm_output_tokens llm_cost_usd
# 0
#
# [1 rows x 35 columns]

# %% [markdown]
# ## 🏆 Medical benchmark leaderboard (MedEmbed-style)
#
# The full benchmark table from the MedEmbed project: every model evaluated on the same
# official medical MTEB tasks, **nDCG@10 + MRR@5 per task**, best score per column in
# **bold**, and your fine-tuned model highlighted in green.
#
# Results are cached in `results/med_benchmarks.json` — re-running only evaluates what's new.
# `QUICK_TASKS` skips TRECCOVID (~171k docs, by far the slowest); switch to
# `med_leaderboard.DEFAULT_TASKS` for the complete 5-task table (~1-2 h extra on a T4).

# %%
from core import med_leaderboard

MODELS = [
    "sentence-transformers/all-MiniLM-L6-v2",
    "BAAI/bge-small-en-v1.5",
    "abhinand/MedEmbed-small-v0.1",
    "models/nfcorpus-bge-small-en-v1.5-ft",   # <- your fine-tuned model (from the run above)
    # Closed-source baseline (opt-in) — OpenAI embeddings on the SAME tasks, for comparison
    # only (never fine-tuned). Needs OPENAI_API_KEY; encoding each corpus over the API costs
    # a few cents. Uncomment to include:
    # "openai:text-embedding-3-small",
]
TASKS = med_leaderboard.QUICK_TASKS  # or med_leaderboard.DEFAULT_TASKS to add TRECCOVID

med_leaderboard.evaluate(models=MODELS, tasks=TASKS)
med_leaderboard.styled(tasks=TASKS)
# Out:
# [evaluating] sentence-transformers/all-MiniLM-L6-v2 on ['MedicalQARetrieval', 'PublicHealthQA', 'NFCorpus', 'ArguAna']
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# [evaluating] BAAI/bge-small-en-v1.5 on ['MedicalQARetrieval', 'PublicHealthQA', 'NFCorpus', 'ArguAna']
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [evaluating] abhinand/MedEmbed-small-v0.1 on ['MedicalQARetrieval', 'PublicHealthQA', 'NFCorpus', 'ArguAna']
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [evaluating] models/nfcorpus-bge-small-en-v1.5-ft on ['MedicalQARetrieval', 'PublicHealthQA', 'NFCorpus', 'ArguAna']
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# <style type="text/css">
# #T_0e326 caption {
#   caption-side: top;
#   font-size: 1.25em;
#   font-weight: bold;
#   padding: 8px;
# }
# #T_0e326 th {
#   text-align: center;
# }
# #T_0e326_row0_col2, #T_0e326_row0_col3, #T_0e326_row0_col4, #T_0e326_row0_col5, #T_0e326_row0_col6, #T_0e326_row0_col8, #T_0e326_row0_col9 {
#   font-weight: bold;
# }
# #T_0e326_row2_col0, #T_0e326_row2_col1, #T_0e326_row2_col2, #T_0e326_row2_col3, #T_0e326_row2_col4, #T_0e326_row2_col5, #T_0e326_row2_col6, #T_0e326_row2_col8, #T_0e326_row2_col9 {
#   background-color: #d8f0d8;
# }
# #T_0e326_row2_col7 {
#   background-color: #d8f0d8;
#   font-weight: bold;
# }
# </style>
# <table id="T_0e326" class="dataframe">
#   <caption>Medical / Clinical related Retrieval Benchmarks</caption>
#   <thead>
#     <tr>
#       <th id="T_0e326_level0_col0" class="col_heading level0 col0" colspan="2"></th>
#       <th id="T_0e326_level0_col2" class="col_heading level0 col2" colspan="2">MedicalQARetrieval</th>
#       <th id="T_0e326_level0_col4" class="col_heading level0 col4" colspan="2">PublicHealthQA</th>
#       <th id="T_0e326_level0_col6" class="col_heading level0 col6" colspan="2">NFCorpus</th>
#       <th id="T_0e326_level0_col8" class="col_heading level0 col8" colspan="2">ArguAna</th>
#     </tr>
#     <tr>
#       <th id="T_0e326_level1_col0" class="col_heading level1 col0" >Model</th>
#       <th id="T_0e326_level1_col1" class="col_heading level1 col1" ># Params</th>
#       <th id="T_0e326_level1_col2" class="col_heading level1 col2" >nDCG@10</th>
#       <th id="T_0e326_level1_col3" class="col_heading level1 col3" >MRR@5</th>
#       <th id="T_0e326_level1_col4" class="col_heading level1 col4" >nDCG@10</th>
#       <th id="T_0e326_level1_col5" class="col_heading level1 col5" >MRR@5</th>
#       <th id="T_0e326_level1_col6" class="col_heading level1 col6" >nDCG@10</th>
#       <th id="T_0e326_level1_col7" class="col_heading level1 col7" >MRR@5</th>
#       <th id="T_0e326_level1_col8" class="col_heading level1 col8" >nDCG@10</th>
#       <th id="T_0e326_level1_col9" class="col_heading level1 col9" >MRR@5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0e326_row0_col0" class="data row0 col0" >abhinand/MedEmbed-small-v0.1</td>
#       <td id="T_0e326_row0_col1" class="data row0 col1" >33M</td>
#       <td id="T_0e326_row0_col2" class="data row0 col2" >70.32</td>
#       <td id="T_0e326_row0_col3" class="data row0 col3" >64.84</td>
#       <td id="T_0e326_row0_col4" class="data row0 col4" >81.80</td>
#       <td id="T_0e326_row0_col5" class="data row0 col5" >76.68</td>
#       <td id="T_0e326_row0_col6" class="data row0 col6" >34.77</td>
#       <td id="T_0e326_row0_col7" class="data row0 col7" >53.17</td>
#       <td id="T_0e326_row0_col8" class="data row0 col8" >61.57</td>
#       <td id="T_0e326_row0_col9" class="data row0 col9" >52.11</td>
#     </tr>
#     <tr>
#       <td id="T_0e326_row1_col0" class="data row1 col0" >BAAI/bge-small-en-v1.5</td>
#       <td id="T_0e326_row1_col1" class="data row1 col1" >33M</td>
#       <td id="T_0e326_row1_col2" class="data row1 col2" >65.56</td>
#       <td id="T_0e326_row1_col3" class="data row1 col3" >59.28</td>
#       <td id="T_0e326_row1_col4" class="data row1 col4" >76.18</td>
#       <td id="T_0e326_row1_col5" class="data row1 col5" >70.60</td>
#       <td id="T_0e326_row1_col6" class="data row1 col6" >33.71</td>
#       <td id="T_0e326_row1_col7" class="data row1 col7" >52.19</td>
#       <td id="T_0e326_row1_col8" class="data row1 col8" >59.50</td>
#       <td id="T_0e326_row1_col9" class="data row1 col9" >49.78</td>
#     </tr>
#     <tr>
#       <td id="T_0e326_row2_col0" class="data row2 col0" >models/nfcorpus-bge-small-en-v1.5-ft</td>
#       <td id="T_0e326_row2_col1" class="data row2 col1" >33M</td>
#       <td id="T_0e326_row2_col2" class="data row2 col2" >62.70</td>
#       <td id="T_0e326_row2_col3" class="data row2 col3" >55.75</td>
#       <td id="T_0e326_row2_col4" class="data row2 col4" >73.49</td>
#       <td id="T_0e326_row2_col5" class="data row2 col5" >67.34</td>
#       <td id="T_0e326_row2_col6" class="data row2 col6" >34.62</td>
#       <td id="T_0e326_row2_col7" class="data row2 col7" >53.82</td>
#       <td id="T_0e326_row2_col8" class="data row2 col8" >55.09</td>
#       <td id="T_0e326_row2_col9" class="data row2 col9" >45.31</td>
#     </tr>
#     <tr>
#       <td id="T_0e326_row3_col0" class="data row3 col0" >sentence-transformers/all-MiniLM-L6-v2</td>
#       <td id="T_0e326_row3_col1" class="data row3 col1" >23M</td>
#       <td id="T_0e326_row3_col2" class="data row3 col2" >60.30</td>
#       <td id="T_0e326_row3_col3" class="data row3 col3" >53.02</td>
#       <td id="T_0e326_row3_col4" class="data row3 col4" >75.81</td>
#       <td id="T_0e326_row3_col5" class="data row3 col5" >69.85</td>
#       <td id="T_0e326_row3_col6" class="data row3 col6" >31.59</td>
#       <td id="T_0e326_row3_col7" class="data row3 col7" >49.89</td>
#       <td id="T_0e326_row3_col8" class="data row3 col8" >50.17</td>
#       <td id="T_0e326_row3_col9" class="data row3 col9" >39.29</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## More experiments (each adds a leaderboard row)

# %%
# Train on the COMPLETE MedEmbed clinical triplets (expert negatives, mining skipped).
# ~232k triplets x 3 epochs is a long T4 run — cap with --sample-size if short on time.
# !python run_pipeline.py --domain medembed --epochs 3 --batch-size 32 --run-label colab-medembed-3ep

# Or the complete medical flashcards:
# !python run_pipeline.py --domain flashcards --epochs 3 --batch-size 32 --run-label colab-flashcards-3ep

# Sweep several open-source base models in ONE run — data prep + triplets happen once, then
# each model is fine-tuned and lands on the leaderboard as its own row:
# !python run_pipeline.py --domain nfcorpus --epochs 3 --batch-size 32 \
#     --base-models BAAI/bge-small-en-v1.5,intfloat/e5-small-v2,thenlper/gte-small \
#     --benchmark --run-label sweep-nfcorpus
# Out:
# [device] cuda  |  base_models=BAAI/bge-small-en-v1.5  domain=medembed  primary_task=MedicalQARetrieval
# [benchmarks] MedicalQARetrieval, PublicHealthQA, NFCorpus, ArguAna
#
# [data] Preparing medical data ...
# {
#   "domain": "medembed",
#   "num_pairs": 21585,
#   "num_eval_queries": 100,
#   "eval_corpus_size": 5000,
#   "pairs_path": "/content/project/data/pairs.jsonl",
#   "eval_path": "/content/project/data/eval.json"
# }
#
# [triplets] Collecting triplets ...
# {
#   "source": "native (dataset ships expert triplets; mining skipped)",
#   "num_triplets": 21585,
#   "triplets_path": "/content/project/data/triplets.jsonl"
# }
#
# ########## base_model = BAAI/bge-small-en-v1.5 ##########
#
# [baseline] MTEB / IR baseline (base model) ...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100% 199/199 [00:00<00:00, 4973.17it/s]
# {
#   "model": "BAAI/bge-small-en-v1.5",
#   "ir": {
#     "ndcg@10": 0.38,
#     "mrr@10": 0.351,
#     "map@100": 0.3575,
#     "recall@10": 0.47,
#     "accuracy@1": 0.29
#   },
#   "mteb": {
#     "task": "MedicalQARetrieval",
#     "ndcg@10": 0.6556,
#     "tasks": {
#       "MedicalQARetrieval": {
#         "ndcg@10": 0.6556,
#         "mrr@5": 0.5928
#       },
#       "PublicHealthQA": {
#         "ndcg@10": 0.7618,
#         "mrr@5": 0.706
#       },
#       "NFCorpus": {
#         "ndcg@10": 0.3371,
#         "mrr@5": 0.5219
#       },
#       "ArguAna": {
#         "ndcg@10": 0.595,
#         "mrr@5": 0.4978
#       }
#     }
#   }
# }
#
# [train] Fine-tuning ...
# Loading weights: 100% 199/199 [00:00<00:00, 4538.33it/s]
# {'loss': '2.729', 'grad_norm': '7.414', 'learning_rate': '4.876e-06', 'epoch': '0.07474'}
# {'loss': '2.206', 'grad_norm': '8.051', 'learning_rate': '9.851e-06', 'epoch': '0.1495'}
# {'loss': '1.888', 'grad_norm': '9.73', 'learning_rate': '1.483e-05', 'epoch': '0.2242'}
# {'loss': '1.789', 'grad_norm': '7.976', 'learning_rate': '1.98e-05', 'epoch': '0.299'}
# {'loss': '1.711', 'grad_norm': '9.268', 'learning_rate': '1.947e-05', 'epoch': '0.3737'}
# {'loss': '1.636', 'grad_norm': '8.559', 'learning_rate': '1.891e-05', 'epoch': '0.4484'}
# {'loss': '1.606', 'grad_norm': '9.766', 'learning_rate': '1.836e-05', 'epoch': '0.5232'}
# {'loss': '1.594', 'grad_norm': '10.18', 'learning_rate': '1.781e-05', 'epoch': '0.5979'}
# {'loss': '1.572', 'grad_norm': '9.686', 'learning_rate': '1.725e-05', 'epoch': '0.6726'}
# {'loss': '1.579', 'grad_norm': '9.954', 'learning_rate': '1.67e-05', 'epoch': '0.7474'}
# {'loss': '1.498', 'grad_norm': '10.26', 'learning_rate': '1.615e-05', 'epoch': '0.8221'}
# {'loss': '1.523', 'grad_norm': '10.5', 'learning_rate': '1.559e-05', 'epoch': '0.8969'}
# {'loss': '1.531', 'grad_norm': '9.442', 'learning_rate': '1.504e-05', 'epoch': '0.9716'}
# {'loss': '1.436', 'grad_norm': '10.49', 'learning_rate': '1.449e-05', 'epoch': '1.046'}
# {'loss': '1.424', 'grad_norm': '8.79', 'learning_rate': '1.393e-05', 'epoch': '1.121'}
# {'loss': '1.341', 'grad_norm': '9.466', 'learning_rate': '1.338e-05', 'epoch': '1.196'}
# {'loss': '1.376', 'grad_norm': '10.22', 'learning_rate': '1.282e-05', 'epoch': '1.271'}
# {'loss': '1.358', 'grad_norm': '8.841', 'learning_rate': '1.227e-05', 'epoch': '1.345'}
# {'loss': '1.354', 'grad_norm': '10.75', 'learning_rate': '1.172e-05', 'epoch': '1.42'}
# {'loss': '1.352', 'grad_norm': '9.273', 'learning_rate': '1.116e-05', 'epoch': '1.495'}
# {'loss': '1.309', 'grad_norm': '11.56', 'learning_rate': '1.061e-05', 'epoch': '1.57'}
# {'loss': '1.289', 'grad_norm': '8.947', 'learning_rate': '1.006e-05', 'epoch': '1.644'}
# {'loss': '1.333', 'grad_norm': '11.47', 'learning_rate': '9.502e-06', 'epoch': '1.719'}
# {'loss': '1.354', 'grad_norm': '10.89', 'learning_rate': '8.948e-06', 'epoch': '1.794'}
# {'loss': '1.276', 'grad_norm': '10.09', 'learning_rate': '8.394e-06', 'epoch': '1.868'}
# {'loss': '1.354', 'grad_norm': '10.55', 'learning_rate': '7.841e-06', 'epoch': '1.943'}
# {'loss': '1.342', 'grad_norm': '9.409', 'learning_rate': '7.287e-06', 'epoch': '2.018'}
# {'loss': '1.3', 'grad_norm': '10.95', 'learning_rate': '6.733e-06', 'epoch': '2.093'}
# {'loss': '1.193', 'grad_norm': '9.95', 'learning_rate': '6.179e-06', 'epoch': '2.167'}
# {'loss': '1.203', 'grad_norm': '9.16', 'learning_rate': '5.626e-06', 'epoch': '2.242'}
# {'loss': '1.239', 'grad_norm': '12.37', 'learning_rate': '5.072e-06', 'epoch': '2.317'}
# {'loss': '1.205', 'grad_norm': '9.796', 'learning_rate': '4.518e-06', 'epoch': '2.392'}
# {'loss': '1.264', 'grad_norm': '8.061', 'learning_rate': '3.965e-06', 'epoch': '2.466'}
# {'loss': '1.155', 'grad_norm': '9.139', 'learning_rate': '3.411e-06', 'epoch': '2.541'}
# {'loss': '1.215', 'grad_norm': '10.67', 'learning_rate': '2.857e-06', 'epoch': '2.616'}
# {'loss': '1.245', 'grad_norm': '10.49', 'learning_rate': '2.303e-06', 'epoch': '2.691'}
# {'loss': '1.193', 'grad_norm': '9.059', 'learning_rate': '1.75e-06', 'epoch': '2.765'}
# {'loss': '1.26', 'grad_norm': '9.457', 'learning_rate': '1.196e-06', 'epoch': '2.84'}
# {'loss': '1.206', 'grad_norm': '9.841', 'learning_rate': '6.423e-07', 'epoch': '2.915'}
# {'loss': '1.272', 'grad_norm': '10.95', 'learning_rate': '8.859e-08', 'epoch': '2.99'}
# {'train_runtime': '382.2', 'train_samples_per_second': '167.8', 'train_steps_per_second': '5.251', 'train_loss': '1.442', 'epoch': '3'}
# Writing model shards: 100% 1/1 [00:00<00:00,  4.01it/s]
# {
#   "base_model": "BAAI/bge-small-en-v1.5",
#   "device": "cuda",
#   "fp16": true,
#   "epochs": 3,
#   "batch_size": 32,
#   "num_train_triplets": 21385,
#   "num_holdout_triplets": 200,
#   "output_dir": "/content/project/models/medembed-bge-small-en-v1.5-ft"
# }
#
# [evaluate] Evaluating fine-tuned model ...
# Loading weights: 100% 199/199 [00:00<00:00, 5229.87it/s]
# {
#   "model": "/content/project/models/medembed-bge-small-en-v1.5-ft",
#   "ir": {
#     "ndcg@10": 0.4216,
#     "mrr@10": 0.3885,
#     "map@100": 0.3937,
#     "recall@10": 0.53,
#     "accuracy@1": 0.33
#   },
#   "triplet_accuracy": 0.79,
#   "mteb": {
#     "task": "MedicalQARetrieval",
#     "ndcg@10": 0.6919,
#     "tasks": {
#       "MedicalQARetrieval": {
#         "ndcg@10": 0.6919,
#         "mrr@5": 0.6369
#       },
#       "PublicHealthQA": {
#         "ndcg@10": 0.7953,
#         "mrr@5": 0.7393
#       },
#       "NFCorpus": {
#         "ndcg@10": 0.3378,
#         "mrr@5": 0.5175
#       },
#       "ArguAna": {
#         "ndcg@10": 0.5988,
#         "mrr@5": 0.5047
#       }
#     }
#   }
# }
#
# [compare] Comparison (before vs after) ...
# {
#   "base_model": "BAAI/bge-small-en-v1.5",
#   "finetuned_model": "/content/project/models/medembed-bge-small-en-v1.5-ft",
#   "headline_ir_ndcg@10_delta": 0.0416,
#   "improved": true,
#   "triplet_accuracy_finetuned": 0.79,
#   "rows": [
#     {
#       "metric": "IR ndcg@10",
#       "baseline": 0.38,
#       "finetuned": 0.4216,
#       "delta": 0.0416
#     },
#     {
#       "metric": "IR mrr@10",
#       "baseline": 0.351,
#       "finetuned": 0.3885,
#       "delta": 0.0375
#     },
#     {
#       "metric": "IR map@100",
#       "baseline": 0.3575,
#       "finetuned": 0.3937,
#       "delta": 0.0362
#     },
#     {
#       "metric": "IR recall@10",
#       "baseline": 0.47,
#       "finetuned": 0.53,
#       "delta": 0.06
#     },
#     {
#       "metric": "MTEB MedicalQARetrieval ndcg@10",
#       "baseline": 0.6556,
#       "finetuned": 0.6919,
#       "delta": 0.0363
#     },
#     {
#       "metric": "MTEB PublicHealthQA ndcg@10",
#       "baseline": 0.7618,
#       "finetuned": 0.7953,
#       "delta": 0.0335
#     },
#     {
#       "metric": "MTEB NFCorpus ndcg@10",
#       "baseline": 0.3371,
#       "finetuned": 0.3378,
#       "delta": 0.0007
#     },
#     {
#       "metric": "MTEB ArguAna ndcg@10",
#       "baseline": 0.595,
#       "finetuned": 0.5988,
#       "delta": 0.0038
#     }
#   ]
# }
#
# === BAAI/bge-small-en-v1.5: IR nDCG@10 delta = 0.0416  ->  IMPROVED ===
#
# === LEADERBOARD (best first) ===
# rank  run_at               run_label           base_model              domain    epochs  ir_ndcg@10_ft  mteb_MedicalQARetrieval_ft  mteb_PublicHealthQA_ft  mteb_NFCorpus_ft  mteb_ArguAna_ft  llm_cost_usd
# 1     2026-07-09 09:13:08  colab-medembed-3ep  BAAI/bge-small-en-v1.5  medembed  3       0.4216         0.6919                      0.7953                  0.3378            0.5988           -
# 2     2026-07-09 08:54:37  colab-nfcorpus-3ep  BAAI/bge-small-en-v1.5  nfcorpus  3       0.376          0.627                       0.7349                  0.3463            0.5509           -

# %% [markdown]
# ## Download the fine-tuned model + results

# %%
# !zip -rq finetuned_model.zip models/ results/
from google.colab import files
files.download("finetuned_model.zip")

# %% [markdown]
# **Use the model afterwards:**
#
# ```python
# from sentence_transformers import SentenceTransformer
# model = SentenceTransformer("models/nfcorpus-bge-small-en-v1.5-ft")
# emb = model.encode(["What are the symptoms of type 2 diabetes?"], normalize_embeddings=True)
# ```

# %% [markdown]
# ## Path B — optional: FastAPI + Streamlit UI behind a public URL

# %%
# Path B (optional) — run the API + UI behind a public cloudflared URL
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 -O cloudflared
# !chmod +x cloudflared

import subprocess, time
subprocess.Popen(["uvicorn", "api.main:app", "--host", "0.0.0.0", "--port", "8000"])
time.sleep(5)
subprocess.Popen(["streamlit", "run", "app/streamlit_app.py", "--server.port", "8501", "--server.headless", "true"])
time.sleep(5)
# !./cloudflared tunnel --url http://localhost:8501 --no-autoupdate
# Out:
# 2026-07-09T09:13:51Z INF Thank you for trying Cloudflare Tunnel. Doing so, without a Cloudflare account, is a quick way to experiment and try it out. However, be aware that these account-less Tunnels have no uptime guarantee, are subject to the Cloudflare Online Services Terms of Use (https://www.cloudflare.com/website-terms/), and Cloudflare reserves the right to investigate your use of Tunnels for violations of such terms. If you intend to use Tunnels in production you should use a pre-created named tunnel by following: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps
# 2026-07-09T09:13:51Z INF Requesting new quick Tunnel on trycloudflare.com...
# 2026-07-09T09:13:54Z INF +--------------------------------------------------------------------------------------------+
# 2026-07-09T09:13:54Z INF |  Your quick Tunnel has been created! Visit it at (it may take some time to be reachable):  |
# 2026-07-09T09:13:54Z INF |  https://became-ending-year-clinics.trycloudflare.com                                      |
# 2026-07-09T09:13:54Z INF +--------------------------------------------------------------------------------------------+
# 2026-07-09T09:13:54Z INF Cannot determine default configuration path. No file [config.yml config.yaml] in [~/.cloudflared ~/.cloudflare-warp ~/cloudflare-warp /etc/cloudflared /usr/local/etc/cloudflared]
# 2026-07-09T09:13:54Z INF Version 2026.7.0 (Checksum 434a04eb237e07d3d4146fc44acdbb411260a94fcb01764f454abe38a09503f3)
# 2026-07-09T09:13:54Z INF GOOS: linux, GOVersion: go1.26.4, GoArch: amd64
# 2026-07-09T09:13:54Z INF Settings: map[ha-connections:1 no-autoupdate:true protocol:quic url:http://localhost:8501]
# 2026-07-09T09:13:54Z INF cloudflared will not automatically update when run from the shell. To enable auto-updates, run cloudflared as a service: https://developers.cloudflare.com/cloudflare-one/connections/connect-apps/configure-tunnels/local-management/as-a-service/
# 2026-07-09T09:13:54Z INF Generated Connector ID: 6f10bdc1-aba1-48e2-aa21-841949cede92
# 2026-07-09T09:13:54Z INF Initial protocol quic
# 2026-07-09T09:13:54Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2026-07-09T09:13:54Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2026-07-09T09:13:54Z INF ICMP proxy will use 172.28.0.12 as source for IPv4
# 2026-07-09T09:13:54Z INF ICMP proxy will use ::1 in zone lo as source for IPv6
# 2026-07-09T09:13:54Z INF Starting metrics server on 127.0.0.1:20241/metrics
# 2026/07/09 09:13:54 failed to sufficiently increase receive buffer size (was: 208 kiB, wanted: 7168 kiB, got: 416 kiB). See https://github.com/quic-go/quic-go/wiki/UDP-Buffer-Sizes for details.
# 2026-07-09T09:13:54Z INF Tunnel connection curve preferences: [X25519MLKEM768 CurveID(65074) CurveP256] connIndex=0 event=0 ip=198.41.192.57
# 2026-07-09T09:13:54Z INF Registered tunnel connection connIndex=0 connection=dc534d48-9657-4e1c-a199-cfa8300a7b2b event=0 ip=198.41.192.57 location=sea01 protocol=quic
# 2026-07-09T09:14:00Z INF +-------------------------------------------------------------------------------------+
# 2026-07-09T09:14:00Z INF |                               CONNECTIVITY PRE-CHECKS                               |
# 2026-07-09T09:14:00Z INF +-------------------------------------------------------------------------------------+
# 2026-07-09T09:14:00Z INF |  COMPONENT         TARGET                     STATUS  DETAILS                       |
# 2026-07-09T09:14:00Z INF |  DNS Resolution    region1.v2.argotunnel.com  PASS    DNS Resolved successfully     |
# 2026-07-09T09:14:00Z INF |  DNS Resolution    region2.v2.argotunnel.com  PASS    DNS Resolved successfully     |
# 2026-07-09T09:14:00Z INF |  UDP Connectivity  region1.v2.argotunnel.com  PASS    QUIC connection successful    |
# 2026-07-09T09:14:00Z INF |  UDP Connectivity  region2.v2.argotunnel.com  PASS    QUIC connection successful    |
# 2026-07-09T09:14:00Z INF |  TCP Connectivity  region1.v2.argotunnel.com  PASS    HTTP/2 connection successful  |
# 2026-07-09T09:14:00Z INF |  TCP Connectivity  region2.v2.argotunnel.com  PASS    HTTP/2 connection successful  |
# 2026-07-09T09:14:00Z INF |  Cloudflare API    api.cloudflare.com:443     PASS    API is reachable              |
# 2026-07-09T09:14:00Z INF |                                                                                     |
# 2026-07-09T09:14:00Z INF |  SUMMARY: Environment is healthy. cloudflared will use 'quic' as primary protocol.  |
# 2026-07-09T09:14:00Z INF +-------------------------------------------------------------------------------------+
# 2026-07-09T09:14:00Z INF precheck component="DNS Resolution" details="DNS Resolved successfully" run_id=2f9a40a2-bde1-46f7-9db9-6fe5c6442197 status=pass target=region1.v2.argotunnel.com
# 2026-07-09T09:14:00Z INF precheck component="DNS Resolution" details="DNS Resolved successfully" run_id=2f9a40a2-bde1-46f7-9db9-6fe5c6442197 status=pass target=region2.v2.argotunnel.com
# 2026-07-09T09:14:00Z INF precheck component="UDP Connectivity" details="QUIC connection successful" run_id=2f9a40a2-bde1-46f7-9db9-6fe5c6442197 status=pass target=region1.v2.argotunnel.com
# 2026-07-09T09:14:00Z INF precheck component="UDP Connectivity" details="QUIC connection successful" run_id=2f9a40a2-bde1-46f7-9db9-6fe5c6442197 status=pass target=region2.v2.argotunnel.com
# 2026-07-09T09:14:00Z INF precheck component="TCP Connectivity" details="HTTP/2 connection successful" run_id=2f9a40a2-bde1-46f7-9db9-6fe5c6442197 status=pass target=region1.v2.argotunnel.com
# 2026-07-09T09:14:00Z INF precheck component="TCP Connectivity" details="HTTP/2 connection successful" run_id=2f9a40a2-bde1-46f7-9db9-6fe5c6442197 status=pass target=region2.v2.argotunnel.com
# 2026-07-09T09:14:00Z INF precheck component="Cloudflare API" details="API is reachable" run_id=2f9a40a2-bde1-46f7-9db9-6fe5c6442197 status=pass target=api.cloudflare.com:443
# 2026-07-09T09:14:00Z INF precheck complete hard_fail=false run_id=2f9a40a2-bde1-46f7-9db9-6fe5c6442197 suggested_protocol=quic
